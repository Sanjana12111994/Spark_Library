# %%
import findspark
import pyspark
from pyspark.sql import *
from pyspark.ml.feature import Imputer
from pyspark.sql.functions import struct
from pyspark.sql import SparkSession, functions as F, types

# %%
findspark.init()
spark = SparkSession.builder.appName('Spark_Imputer').master("local").getOrCreate()

# %%
df = spark.read.load("MOCK_DATA.csv",format="csv", inferSchema="true", header="true")
df.show(40)
# Out:
# +----+----------+-------------+--------------------+------+---------------+----+----+
# |  id|first_name|    last_name|               email|gender|     ip_address| age|age1|
# +----+----------+-------------+--------------------+------+---------------+----+----+
# |   1|  Christal|        Deval|   cdeval0@google.es|Female|   78.41.59.167|null|null|
# |   2|   Ginevra|      Bosanko|gbosanko1@marketw...|Female|   13.49.23.173|null|null|
# |   3|     Milka|       Govini|    mgovini2@mtv.com|Female|220.205.250.120|   3|   3|
# |   4|       Ali|    Flaunders|aflaunders3@cisco...|  Male|  108.75.25.221|  85|  85|
# |   5|    Silvia|      Mitcham|   smitcham4@mtv.com|Female|  83.90.147.253|null|null|
# |   6|    Elicia|      Mattson|emattson5@typepad...|Female| 63.223.250.214|null|null|
# |   7|    Barton|    Duesberry| bduesberry6@soup.io|  Male|   97.254.22.99|null|null|
# |   8| Selestina|     Gartrell|sgartrell7@engadg...|Female|184.108.174.192|null|null|
# |   9|    Saudra|         Cadd|scadd8@friendfeed...|Female|  232.247.42.85|  28|  28|
# |  10|     Laird|       Marham|lmarham9@edublogs...|  Male|151.204.235.144|  26|  26|
# |  11|     Lanie|       Caught|lcaughta@latimes.com|  Male|251.178.140.168|   8|   8|
# |  12|       Orv|   MacCoveney|omaccoveneyb@t-on...|  Male|187.179.229.243|null|null|
# |  13|      Davy|        Quinn|dquinnc@springer.com|  Male|  44.214.34.194|  48|  48|
# |  14|     Denis|     Mulheron|dmulherond@gizmod...|  Male|  100.94.115.39|null|null|
# |  15|  Ezechiel|        Hundy|  ehundye@rambler.ru|  Male| 22.107.110.146|   2|   2|
# |  16|     Lyell|        Edmed|   ledmedf@bbc.co.uk|  Male| 196.144.117.98|null|null|
# |  17|      Meir|     Brundall|mbrundallg@shinys...|  Male|   95.25.191.99|  64|  64|
# |  18|       Hal|        Kield|hkieldh@bandcamp.com|  Male|   106.49.31.40|  31|  31|
# |  19|     Alwyn|     Hartwell|ahartwelli@jiathi...|  Male|   49.96.245.84|  74|  74|
# |  20|    Myrtia|         Fick|  mfickj@tinypic.com|Female| 151.107.142.49|null|null|
# |  21|   Kikelia|       Aggett| kaggettk@ustream.tv|Female|   242.48.84.57|null|null|
# |null|    Glynis|    Rebillard|grebillardl@censu...|Female|   154.20.223.1|  44|  44|
# |  23|Sigismundo|     Filimore|sfilimorem@gravat...|  Male| 244.108.227.72|null|null|
# |  24|     Ossie|       Meneux|omeneuxn@bravesit...|  Male| 139.12.122.176|  84|  84|
# |  25|    Albina|     Thickins|athickinso@cornel...|Female|  91.242.29.247|null|null|
# |  26|   Melinde|Aleksandrikin|maleksandrikinp@w...|Female| 136.239.176.67|  49|  49|
# |  27|     Tania|      Arnault|tarnaultq@so-net....|Female|    90.26.2.104|  86|  86|
# |  28|    Boycie|      McIlroy| bmcilroyr@apple.com|  Male|  10.109.217.80|  45|  45|
# |  29|   Bartram|         Manz|      bmanzs@ted.com|  Male|  46.163.135.60|  46|  46|
# |  30|       Isa|        Soane|isoanet@virginia.edu|  Male|113.130.165.117|null|null|
# |  31|   Alyosha|       Sapson|asapsonu@livejour...|  Male| 145.38.128.164|null|null|
# |null|   Patrice|       Kemson|    pkemsonv@mlb.com|Female|175.234.143.220|  56|  56|
# |  33|      Elka|  Weatherburn|eweatherburnw@tin...|Female| 160.30.131.161|  92|  92|
# |  34|   Austine|        Gietz|     agietzx@nih.gov|Female|  82.70.240.221|  22|  22|
# |  35|    Wileen|        Juste| wjustey@example.com|Female|  1.126.236.224|null|null|
# |null|      Adah|     McVicker|amcvickerz@symant...|Female|   0.167.48.238|  28|  28|
# |  37| Annemarie|         Tidy|        atidy10@g.co|Female|     7.30.58.23|  92|  92|
# |  38|   Willdon|       Keward|wkeward11@dyndns.org|  Male|  166.91.207.47|null|null|
# |  39|   Marjory|      Antonat|mantonat12@bbc.co.uk|Female| 100.104.34.127|  15|  15|
# |  40|    Lonnie|     McIndrew|lmcindrew13@webs.com|Female|  72.177.125.70|null|null|
# +----+----------+-------------+--------------------+------+---------------+----+----+
# only showing top 40 rows

# %%
col = "age"

#Try with type = mean or median

type="median"
# type3 = "median"
imputer = Imputer(inputCols=[col], outputCols=[col+"_imputed_"+type]).setStrategy(type)

model = imputer.fit(df)

model.transform(df).show()
# Out:
# +---+----------+----------+--------------------+------+---------------+----+----+------------------+
# | id|first_name| last_name|               email|gender|     ip_address| age|age1|age_imputed_median|
# +---+----------+----------+--------------------+------+---------------+----+----+------------------+
# |  1|  Christal|     Deval|   cdeval0@google.es|Female|   78.41.59.167|null|null|                53|
# |  2|   Ginevra|   Bosanko|gbosanko1@marketw...|Female|   13.49.23.173|null|null|                53|
# |  3|     Milka|    Govini|    mgovini2@mtv.com|Female|220.205.250.120|   3|   3|                 3|
# |  4|       Ali| Flaunders|aflaunders3@cisco...|  Male|  108.75.25.221|  85|  85|                85|
# |  5|    Silvia|   Mitcham|   smitcham4@mtv.com|Female|  83.90.147.253|null|null|                53|
# |  6|    Elicia|   Mattson|emattson5@typepad...|Female| 63.223.250.214|null|null|                53|
# |  7|    Barton| Duesberry| bduesberry6@soup.io|  Male|   97.254.22.99|null|null|                53|
# |  8| Selestina|  Gartrell|sgartrell7@engadg...|Female|184.108.174.192|null|null|                53|
# |  9|    Saudra|      Cadd|scadd8@friendfeed...|Female|  232.247.42.85|  28|  28|                28|
# | 10|     Laird|    Marham|lmarham9@edublogs...|  Male|151.204.235.144|  26|  26|                26|
# | 11|     Lanie|    Caught|lcaughta@latimes.com|  Male|251.178.140.168|   8|   8|                 8|
# | 12|       Orv|MacCoveney|omaccoveneyb@t-on...|  Male|187.179.229.243|null|null|                53|
# | 13|      Davy|     Quinn|dquinnc@springer.com|  Male|  44.214.34.194|  48|  48|                48|
# | 14|     Denis|  Mulheron|dmulherond@gizmod...|  Male|  100.94.115.39|null|null|                53|
# | 15|  Ezechiel|     Hundy|  ehundye@rambler.ru|  Male| 22.107.110.146|   2|   2|                 2|
# | 16|     Lyell|     Edmed|   ledmedf@bbc.co.uk|  Male| 196.144.117.98|null|null|                53|
# | 17|      Meir|  Brundall|mbrundallg@shinys...|  Male|   95.25.191.99|  64|  64|                64|
# | 18|       Hal|     Kield|hkieldh@bandcamp.com|  Male|   106.49.31.40|  31|  31|                31|
# | 19|     Alwyn|  Hartwell|ahartwelli@jiathi...|  Male|   49.96.245.84|  74|  74|                74|
# | 20|    Myrtia|      Fick|  mfickj@tinypic.com|Female| 151.107.142.49|null|null|                53|
# +---+----------+----------+--------------------+------+---------------+----+----+------------------+
# only showing top 20 rows

# %%
# df = df.dropna()
# freq = df.stat.freqItems(df.columns,0.4)
# col = "age"+"_freqItems"

# %%
# mode = freq.collect()[0][6]
# mode = mode[0]
# print(mode)

# %%
# freq.show()

# %%
#Mode
df = spark.read.load("MOCK_DATA.csv",format="csv", inferSchema="true", header="true")
#Specify the list of input columns you want to impute
cols = ["age","age1"]

for col in cols:
    
    df_mode= df.where(df[col].isNotNull())
    df_mode.dropna()
    cnts = df_mode.groupBy(col).count().orderBy("count",ascending=False)
    mode = cnts.take(1)[0][0]
    print("Mode= ", mode)

    df = df.na.fill(mode)
df.show(40)
# Out:
# Mode=  86
# Mode=  86
# +---+----------+-------------+--------------------+------+---------------+---+----+
# | id|first_name|    last_name|               email|gender|     ip_address|age|age1|
# +---+----------+-------------+--------------------+------+---------------+---+----+
# |  1|  Christal|        Deval|   cdeval0@google.es|Female|   78.41.59.167| 86|  86|
# |  2|   Ginevra|      Bosanko|gbosanko1@marketw...|Female|   13.49.23.173| 86|  86|
# |  3|     Milka|       Govini|    mgovini2@mtv.com|Female|220.205.250.120|  3|   3|
# |  4|       Ali|    Flaunders|aflaunders3@cisco...|  Male|  108.75.25.221| 85|  85|
# |  5|    Silvia|      Mitcham|   smitcham4@mtv.com|Female|  83.90.147.253| 86|  86|
# |  6|    Elicia|      Mattson|emattson5@typepad...|Female| 63.223.250.214| 86|  86|
# |  7|    Barton|    Duesberry| bduesberry6@soup.io|  Male|   97.254.22.99| 86|  86|
# |  8| Selestina|     Gartrell|sgartrell7@engadg...|Female|184.108.174.192| 86|  86|
# |  9|    Saudra|         Cadd|scadd8@friendfeed...|Female|  232.247.42.85| 28|  28|
# | 10|     Laird|       Marham|lmarham9@edublogs...|  Male|151.204.235.144| 26|  26|
# | 11|     Lanie|       Caught|lcaughta@latimes.com|  Male|251.178.140.168|  8|   8|
# | 12|       Orv|   MacCoveney|omaccoveneyb@t-on...|  Male|187.179.229.243| 86|  86|
# | 13|      Davy|        Quinn|dquinnc@springer.com|  Male|  44.214.34.194| 48|  48|
# | 14|     Denis|     Mulheron|dmulherond@gizmod...|  Male|  100.94.115.39| 86|  86|
# | 15|  Ezechiel|        Hundy|  ehundye@rambler.ru|  Male| 22.107.110.146|  2|   2|
# | 16|     Lyell|        Edmed|   ledmedf@bbc.co.uk|  Male| 196.144.117.98| 86|  86|
# | 17|      Meir|     Brundall|mbrundallg@shinys...|  Male|   95.25.191.99| 64|  64|
# | 18|       Hal|        Kield|hkieldh@bandcamp.com|  Male|   106.49.31.40| 31|  31|
# | 19|     Alwyn|     Hartwell|ahartwelli@jiathi...|  Male|   49.96.245.84| 74|  74|
# | 20|    Myrtia|         Fick|  mfickj@tinypic.com|Female| 151.107.142.49| 86|  86|
# | 21|   Kikelia|       Aggett| kaggettk@ustream.tv|Female|   242.48.84.57| 86|  86|
# | 86|    Glynis|    Rebillard|grebillardl@censu...|Female|   154.20.223.1| 44|  44|
# | 23|Sigismundo|     Filimore|sfilimorem@gravat...|  Male| 244.108.227.72| 86|  86|
# | 24|     Ossie|       Meneux|omeneuxn@bravesit...|  Male| 139.12.122.176| 84|  84|
# | 25|    Albina|     Thickins|athickinso@cornel...|Female|  91.242.29.247| 86|  86|
# | 26|   Melinde|Aleksandrikin|maleksandrikinp@w...|Female| 136.239.176.67| 49|  49|
# | 27|     Tania|      Arnault|tarnaultq@so-net....|Female|    90.26.2.104| 86|  86|
# | 28|    Boycie|      McIlroy| bmcilroyr@apple.com|  Male|  10.109.217.80| 45|  45|
# | 29|   Bartram|         Manz|      bmanzs@ted.com|  Male|  46.163.135.60| 46|  46|
# | 30|       Isa|        Soane|isoanet@virginia.edu|  Male|113.130.165.117| 86|  86|
# | 31|   Alyosha|       Sapson|asapsonu@livejour...|  Male| 145.38.128.164| 86|  86|
# | 86|   Patrice|       Kemson|    pkemsonv@mlb.com|Female|175.234.143.220| 56|  56|
# | 33|      Elka|  Weatherburn|eweatherburnw@tin...|Female| 160.30.131.161| 92|  92|
# | 34|   Austine|        Gietz|     agietzx@nih.gov|Female|  82.70.240.221| 22|  22|
# | 35|    Wileen|        Juste| wjustey@example.com|Female|  1.126.236.224| 86|  86|
# | 86|      Adah|     McVicker|amcvickerz@symant...|Female|   0.167.48.238| 28|  28|
# | 37| Annemarie|         Tidy|        atidy10@g.co|Female|     7.30.58.23| 92|  92|
# | 38|   Willdon|       Keward|wkeward11@dyndns.org|  Male|  166.91.207.47| 86|  86|
# | 39|   Marjory|      Antonat|mantonat12@bbc.co.uk|Female| 100.104.34.127| 15|  15|
# | 40|    Lonnie|     McIndrew|lmcindrew13@webs.com|Female|  72.177.125.70| 86|  86|
# +---+----------+-------------+--------------------+------+---------------+---+----+
# only showing top 40 rows

# %%
#Forward Fill
import sys
from pyspark.sql import Window
from pyspark.sql.functions import last, first  
from pyspark.sql import functions as F

df = spark.read.load("MOCK_DATA.csv",format="csv", inferSchema="true", header="true")
df = df.withColumn('dummy', F.lit(1))


#Set the window dimension
window_f = Window.partitionBy('dummy')\
               .rowsBetween(-sys.maxsize, 0)

#Specify the list of input columns you want to impute
cols = ["age","age1"]

for col in cols:
    print(col)
    # define the forward-filled column
    f_filled_column = last(df[col], ignorenulls=True).over(window_f)

    # do the fill
    df_f_filled = df.withColumn('f_fill_'+col, f_filled_column)
    df = df_f_filled

    
#drop the dummy column
df = df.drop('dummy')

# show the imputed df 

df.show(40)
# Out:
# age
# age1
# +----+----------+-------------+--------------------+------+---------------+----+----+----------+-----------+
# |  id|first_name|    last_name|               email|gender|     ip_address| age|age1|f_fill_age|f_fill_age1|
# +----+----------+-------------+--------------------+------+---------------+----+----+----------+-----------+
# |   1|  Christal|        Deval|   cdeval0@google.es|Female|   78.41.59.167|null|null|      null|       null|
# |   2|   Ginevra|      Bosanko|gbosanko1@marketw...|Female|   13.49.23.173|null|null|      null|       null|
# |   3|     Milka|       Govini|    mgovini2@mtv.com|Female|220.205.250.120|   3|   3|         3|          3|
# |   4|       Ali|    Flaunders|aflaunders3@cisco...|  Male|  108.75.25.221|  85|  85|        85|         85|
# |   5|    Silvia|      Mitcham|   smitcham4@mtv.com|Female|  83.90.147.253|null|null|        85|         85|
# |   6|    Elicia|      Mattson|emattson5@typepad...|Female| 63.223.250.214|null|null|        85|         85|
# |   7|    Barton|    Duesberry| bduesberry6@soup.io|  Male|   97.254.22.99|null|null|        85|         85|
# |   8| Selestina|     Gartrell|sgartrell7@engadg...|Female|184.108.174.192|null|null|        85|         85|
# |   9|    Saudra|         Cadd|scadd8@friendfeed...|Female|  232.247.42.85|  28|  28|        28|         28|
# |  10|     Laird|       Marham|lmarham9@edublogs...|  Male|151.204.235.144|  26|  26|        26|         26|
# |  11|     Lanie|       Caught|lcaughta@latimes.com|  Male|251.178.140.168|   8|   8|         8|          8|
# |  12|       Orv|   MacCoveney|omaccoveneyb@t-on...|  Male|187.179.229.243|null|null|         8|          8|
# |  13|      Davy|        Quinn|dquinnc@springer.com|  Male|  44.214.34.194|  48|  48|        48|         48|
# |  14|     Denis|     Mulheron|dmulherond@gizmod...|  Male|  100.94.115.39|null|null|        48|         48|
# |  15|  Ezechiel|        Hundy|  ehundye@rambler.ru|  Male| 22.107.110.146|   2|   2|         2|          2|
# |  16|     Lyell|        Edmed|   ledmedf@bbc.co.uk|  Male| 196.144.117.98|null|null|         2|          2|
# |  17|      Meir|     Brundall|mbrundallg@shinys...|  Male|   95.25.191.99|  64|  64|        64|         64|
# |  18|       Hal|        Kield|hkieldh@bandcamp.com|  Male|   106.49.31.40|  31|  31|        31|         31|
# |  19|     Alwyn|     Hartwell|ahartwelli@jiathi...|  Male|   49.96.245.84|  74|  74|        74|         74|
# |  20|    Myrtia|         Fick|  mfickj@tinypic.com|Female| 151.107.142.49|null|null|        74|         74|
# |  21|   Kikelia|       Aggett| kaggettk@ustream.tv|Female|   242.48.84.57|null|null|        74|         74|
# |null|    Glynis|    Rebillard|grebillardl@censu...|Female|   154.20.223.1|  44|  44|        44|         44|
# |  23|Sigismundo|     Filimore|sfilimorem@gravat...|  Male| 244.108.227.72|null|null|        44|         44|
# |  24|     Ossie|       Meneux|omeneuxn@bravesit...|  Male| 139.12.122.176|  84|  84|        84|         84|
# |  25|    Albina|     Thickins|athickinso@cornel...|Female|  91.242.29.247|null|null|        84|         84|
# |  26|   Melinde|Aleksandrikin|maleksandrikinp@w...|Female| 136.239.176.67|  49|  49|        49|         49|
# |  27|     Tania|      Arnault|tarnaultq@so-net....|Female|    90.26.2.104|  86|  86|        86|         86|
# |  28|    Boycie|      McIlroy| bmcilroyr@apple.com|  Male|  10.109.217.80|  45|  45|        45|         45|
# |  29|   Bartram|         Manz|      bmanzs@ted.com|  Male|  46.163.135.60|  46|  46|        46|         46|
# |  30|       Isa|        Soane|isoanet@virginia.edu|  Male|113.130.165.117|null|null|        46|         46|
# |  31|   Alyosha|       Sapson|asapsonu@livejour...|  Male| 145.38.128.164|null|null|        46|         46|
# |null|   Patrice|       Kemson|    pkemsonv@mlb.com|Female|175.234.143.220|  56|  56|        56|         56|
# |  33|      Elka|  Weatherburn|eweatherburnw@tin...|Female| 160.30.131.161|  92|  92|        92|         92|
# |  34|   Austine|        Gietz|     agietzx@nih.gov|Female|  82.70.240.221|  22|  22|        22|         22|
# |  35|    Wileen|        Juste| wjustey@example.com|Female|  1.126.236.224|null|null|        22|         22|
# |null|      Adah|     McVicker|amcvickerz@symant...|Female|   0.167.48.238|  28|  28|        28|         28|
# |  37| Annemarie|         Tidy|        atidy10@g.co|Female|     7.30.58.23|  92|  92|        92|         92|
# |  38|   Willdon|       Keward|wkeward11@dyndns.org|  Male|  166.91.207.47|null|null|        92|         92|
# |  39|   Marjory|      Antonat|mantonat12@bbc.co.uk|Female| 100.104.34.127|  15|  15|        15|         15|
# |  40|    Lonnie|     McIndrew|lmcindrew13@webs.com|Female|  72.177.125.70|null|null|        15|         15|
# +----+----------+-------------+--------------------+------+---------------+----+----+----------+-----------+
# only showing top 40 rows

# %%
#Backward Fill
import sys
from pyspark.sql import Window
from pyspark.sql.functions import last, first  
from pyspark.sql import functions as F

df = spark.read.load("MOCK_DATA.csv",format="csv", inferSchema="true", header="true")
df = df.withColumn('dummy', F.lit(1))

#Set the window dimension
window_b = Window.partitionBy('dummy')\
               .rowsBetween(0,sys.maxsize)

#Specify the list of input columns you want to impute
cols = ["age","age1"]

for col in cols:

    # define the backward-filled column
    b_filled_column = first(df[col], ignorenulls=True).over(window_b)


    # do the fill
    df_b_filled = df.withColumn('b_fill_'+col, b_filled_column)
    
    df = df_b_filled

df = df.drop('dummy')

# show the imputed df 

df.show(40)
# Out:
# +----+----------+-------------+--------------------+------+---------------+----+----+----------+-----------+
# |  id|first_name|    last_name|               email|gender|     ip_address| age|age1|b_fill_age|b_fill_age1|
# +----+----------+-------------+--------------------+------+---------------+----+----+----------+-----------+
# |   1|  Christal|        Deval|   cdeval0@google.es|Female|   78.41.59.167|null|null|         3|          3|
# |   2|   Ginevra|      Bosanko|gbosanko1@marketw...|Female|   13.49.23.173|null|null|         3|          3|
# |   3|     Milka|       Govini|    mgovini2@mtv.com|Female|220.205.250.120|   3|   3|         3|          3|
# |   4|       Ali|    Flaunders|aflaunders3@cisco...|  Male|  108.75.25.221|  85|  85|        85|         85|
# |   5|    Silvia|      Mitcham|   smitcham4@mtv.com|Female|  83.90.147.253|null|null|        28|         28|
# |   6|    Elicia|      Mattson|emattson5@typepad...|Female| 63.223.250.214|null|null|        28|         28|
# |   7|    Barton|    Duesberry| bduesberry6@soup.io|  Male|   97.254.22.99|null|null|        28|         28|
# |   8| Selestina|     Gartrell|sgartrell7@engadg...|Female|184.108.174.192|null|null|        28|         28|
# |   9|    Saudra|         Cadd|scadd8@friendfeed...|Female|  232.247.42.85|  28|  28|        28|         28|
# |  10|     Laird|       Marham|lmarham9@edublogs...|  Male|151.204.235.144|  26|  26|        26|         26|
# |  11|     Lanie|       Caught|lcaughta@latimes.com|  Male|251.178.140.168|   8|   8|         8|          8|
# |  12|       Orv|   MacCoveney|omaccoveneyb@t-on...|  Male|187.179.229.243|null|null|        48|         48|
# |  13|      Davy|        Quinn|dquinnc@springer.com|  Male|  44.214.34.194|  48|  48|        48|         48|
# |  14|     Denis|     Mulheron|dmulherond@gizmod...|  Male|  100.94.115.39|null|null|         2|          2|
# |  15|  Ezechiel|        Hundy|  ehundye@rambler.ru|  Male| 22.107.110.146|   2|   2|         2|          2|
# |  16|     Lyell|        Edmed|   ledmedf@bbc.co.uk|  Male| 196.144.117.98|null|null|        64|         64|
# |  17|      Meir|     Brundall|mbrundallg@shinys...|  Male|   95.25.191.99|  64|  64|        64|         64|
# |  18|       Hal|        Kield|hkieldh@bandcamp.com|  Male|   106.49.31.40|  31|  31|        31|         31|
# |  19|     Alwyn|     Hartwell|ahartwelli@jiathi...|  Male|   49.96.245.84|  74|  74|        74|         74|
# |  20|    Myrtia|         Fick|  mfickj@tinypic.com|Female| 151.107.142.49|null|null|        44|         44|
# |  21|   Kikelia|       Aggett| kaggettk@ustream.tv|Female|   242.48.84.57|null|null|        44|         44|
# |null|    Glynis|    Rebillard|grebillardl@censu...|Female|   154.20.223.1|  44|  44|        44|         44|
# |  23|Sigismundo|     Filimore|sfilimorem@gravat...|  Male| 244.108.227.72|null|null|        84|         84|
# |  24|     Ossie|       Meneux|omeneuxn@bravesit...|  Male| 139.12.122.176|  84|  84|        84|         84|
# |  25|    Albina|     Thickins|athickinso@cornel...|Female|  91.242.29.247|null|null|        49|         49|
# |  26|   Melinde|Aleksandrikin|maleksandrikinp@w...|Female| 136.239.176.67|  49|  49|        49|         49|
# |  27|     Tania|      Arnault|tarnaultq@so-net....|Female|    90.26.2.104|  86|  86|        86|         86|
# |  28|    Boycie|      McIlroy| bmcilroyr@apple.com|  Male|  10.109.217.80|  45|  45|        45|         45|
# |  29|   Bartram|         Manz|      bmanzs@ted.com|  Male|  46.163.135.60|  46|  46|        46|         46|
# |  30|       Isa|        Soane|isoanet@virginia.edu|  Male|113.130.165.117|null|null|        56|         56|
# |  31|   Alyosha|       Sapson|asapsonu@livejour...|  Male| 145.38.128.164|null|null|        56|         56|
# |null|   Patrice|       Kemson|    pkemsonv@mlb.com|Female|175.234.143.220|  56|  56|        56|         56|
# |  33|      Elka|  Weatherburn|eweatherburnw@tin...|Female| 160.30.131.161|  92|  92|        92|         92|
# |  34|   Austine|        Gietz|     agietzx@nih.gov|Female|  82.70.240.221|  22|  22|        22|         22|
# |  35|    Wileen|        Juste| wjustey@example.com|Female|  1.126.236.224|null|null|        28|         28|
# |null|      Adah|     McVicker|amcvickerz@symant...|Female|   0.167.48.238|  28|  28|        28|         28|
# |  37| Annemarie|         Tidy|        atidy10@g.co|Female|     7.30.58.23|  92|  92|        92|         92|
# |  38|   Willdon|       Keward|wkeward11@dyndns.org|  Male|  166.91.207.47|null|null|        15|         15|
# |  39|   Marjory|      Antonat|mantonat12@bbc.co.uk|Female| 100.104.34.127|  15|  15|        15|         15|
# |  40|    Lonnie|     McIndrew|lmcindrew13@webs.com|Female|  72.177.125.70|null|null|        58|         58|
# +----+----------+-------------+--------------------+------+---------------+----+----+----------+-----------+
# only showing top 40 rows
